# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('results.csv')
df.describe()
# Out:
#                 id   account_id  standard_qty     gloss_qty    poster_qty  \
# count  6912.000000  6912.000000   6087.000000   5894.000000   5763.000000
# mean   3456.500000  2662.362847    318.440283    172.000848    125.567586
# std    1995.466863  1011.454865    451.411907    386.972197    548.844922
# min       1.000000  1001.000000      1.000000      1.000000      1.000000
# 25%    1728.750000  1741.000000     98.000000     19.000000     16.000000
# 50%    3456.500000  2611.000000    301.000000     39.000000     33.000000
# 75%    5184.250000  3471.000000    496.000000    198.750000    157.500000
# max    6912.000000  4501.000000  22591.000000  14281.000000  28262.000000
#
#               total  standard_amt_usd  gloss_amt_usd  poster_amt_usd  \
# count   6892.000000       6912.000000    6912.000000     6912.000000
# mean     533.337928       1399.355692    1098.547420      850.116539
# std      762.089514       2175.706615    2715.116802     4086.988574
# ...

# %%
plt.scatter(df['standard_amt_usd'], df['gloss_amt_usd'])
plt.xlabel('standard_qty')
plt.ylabel('gloss_qty')
# Out:
# Text(0, 0.5, 'gloss_qty')
